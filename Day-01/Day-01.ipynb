# %% [markdown]
# # Python for interview Preparation

# %%
# Python developer, Data Engineer, Data Analyst, ML Engineer, GenAI

# %%
# Python History
# Python is developed by Guido Van Rossum in 1991.
# Popular applications develop in python include: Instagram, facebook, Netflix, Quora.

# %% [markdown]
# # Interview Questions from Python

# %% [raw]
# Q-1: Python is pure object oriented programming language or not?
# Ans: NO
# Python is oop language but not Pure.
# Java is pure oop language.
# C is popl
#
# Q-2: Python is Case sensitive or not?
# Ans: Yes
#
# Q-3: Python is Compiler or Interpreter?
# Ans: Compiler and Interpreter
#
# Q-4: Python is platform independent language or not?
# Ans: Yes, python is platform independent
#
# Q-5: In which language Python is develop?
# Ans: CPython : develop in C language
# JPython : develop in Java language
# PyPy: develop in python
#
# Q-6: Which is fastest language out of C, C++, Java, Python?
# Ans: C is fastest, Python is slowest

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# # variable in python

# %%
a = 10
b = 20.5
c = 'Hello'
d = True
e = None
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'NoneType'>

# %% [markdown]
# # Rules to define a variable name in python

# %%
# 1. Don't start the variable name by a number.
# 2. Variable name must be start by either character or underscore.
# 3. Special symbols are not allowed in variable name.
# 4. Hyphen and spaces are not allowed inside the name.

# %% [markdown]
# # Delete the variable in python

# %%
var = 100

# %%
del var

# %%
print(var)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(var)
#
# NameError: name 'var' is not defined

# %%
# Q: swap the two strings/ number without using temp variables?
a = "Hello"
b = 100
a,b = b,a
print(a, b)
# Out:
# 100 Hello

# %%
# Q: swap the two number without using temp variable with XOR operator?
a = 10
b = 20
print(a,b)
a = a^b
b = a^b
a = a^b
print(a,b)
# Out:
# 10 20
# 20 10

# %%
print("CR")
# Out:
# CR
